# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
    
    
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Country": city_country,
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | abha
# Processing Record 5 of Set 1 | kebumen
# Processing Record 6 of Set 1 | zenzeli
# Processing Record 7 of Set 1 | mweka
# Processing Record 8 of Set 1 | xiongzhou
# Processing Record 9 of Set 1 | aasiaat
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | sanary-sur-mer
# Processing Record 12 of Set 1 | airai
# Processing Record 13 of Set 1 | hami
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | smithers
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | lamu
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | bathsheba
# Processing Record 23 of Set 1 | geraldton
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | chelyabinsk
# Processing Record 28 of Set 1 | turayf
# Processing Record 29 of Set 1 | marsh harbour
# Processing Record 30 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 31 of Set 1 | kavieng
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | fernie
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | codrington
# Processing Record 36 of Set 1 | fallon
# Processing Record 37 of Set 1 | paka
# Processing Record 38 of Set 1 | saint george
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | sulangan
# Processing Record 43 of Set 1 | andenes
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | touros
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | ahipara
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | kayerkan
# Processing Record 1 of Set 2 | fare
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | soto la marina
# Processing Record 5 of Set 2 | kruisfontein
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | nurota
# Processing Record 9 of Set 2 | yuli
# Processing Record 10 of Set 2 | santa maria
# Processing Record 11 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 2 | burica
# City not found. Skipping...
# Processing Record 13 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | teya
# Processing Record 16 of Set 2 | ndioum
# Processing Record 17 of Set 2 | katherine
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | koslan
# Processing Record 21 of Set 2 | iquique
# Processing Record 22 of Set 2 | marovoay
# Processing Record 23 of Set 2 | marawi
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | kerrville
# Processing Record 26 of Set 2 | nisia floresta
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | dahuk
# Processing Record 29 of Set 2 | provideniya
# Processing Record 30 of Set 2 | belmonte
# Processing Record 31 of Set 2 | roma
# Processing Record 32 of Set 2 | puerto escondido
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | laguna
# Processing Record 35 of Set 2 | aklavik
# Processing Record 36 of Set 2 | carauari
# Processing Record 37 of Set 2 | vao
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | faanui
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | tocopilla
# Processing Record 42 of Set 2 | mayumba
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | coahuayana
# Processing Record 45 of Set 2 | taoudenni
# Processing Record 46 of Set 2 | san cristobal
# Processing Record 47 of Set 2 | mayo
# Processing Record 48 of Set 2 | thinadhoo
# Processing Record 49 of Set 2 | cap malheureux
# Processing Record 50 of Set 2 | sehithwa
# Processing Record 1 of Set 3 | miraflores
# Processing Record 2 of Set 3 | bilma
# Processing Record 3 of Set 3 | camana
# Processing Record 4 of Set 3 | uruzgan
# Processing Record 5 of Set 3 | norman wells
# Processing Record 6 of Set 3 | mobile
# Processing Record 7 of Set 3 | severo-kurilsk
# Processing Record 8 of Set 3 | kokopo
# Processing Record 9 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 3 | san quintin
# Processing Record 11 of Set 3 | nhulunbuy
# Processing Record 12 of Set 3 | leningradskiy
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | grand-santi
# Processing Record 16 of Set 3 | doume
# Processing Record 17 of Set 3 | kolhapur
# Processing Record 18 of Set 3 | chokurdakh
# Processing Record 19 of Set 3 | saldanha
# Processing Record 20 of Set 3 | dakar
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | kushima
# Processing Record 23 of Set 3 | alofi
# Processing Record 24 of Set 3 | dicabisagan
# Processing Record 25 of Set 3 | auki
# Processing Record 26 of Set 3 | akom
# Processing Record 27 of Set 3 | naze
# Processing Record 28 of Set 3 | ancud
# Processing Record 29 of Set 3 | esperance
# Processing Record 30 of Set 3 | talnakh
# Processing Record 31 of Set 3 | rocha
# Processing Record 32 of Set 3 | goldap
# Processing Record 33 of Set 3 | vila velha
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | nerchinskiy zavod
# Processing Record 36 of Set 3 | fuerte olimpo
# Processing Record 37 of Set 3 | cedar falls
# Processing Record 38 of Set 3 | yvetot
# Processing Record 39 of Set 3 | lebu
# Processing Record 40 of Set 3 | hamilton
# Processing Record 41 of Set 3 | nikolskoye
# Processing Record 42 of Set 3 | lerwick
# Processing Record 43 of Set 3 | quatre cocos
# Processing Record 44 of Set 3 | maradi
# Processing Record 45 of Set 3 | sabaudia
# Processing Record 46 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | ojinaga
# Processing Record 49 of Set 3 | cerritos
# Processing Record 50 of Set 3 | harper
# Processing Record 1 of Set 4 | abu samrah
# Processing Record 2 of Set 4 | kungurtug
# Processing Record 3 of Set 4 | innisfail
# Processing Record 4 of Set 4 | palu
# Processing Record 5 of Set 4 | haines junction
# Processing Record 6 of Set 4 | shubarkuduk
# Processing Record 7 of Set 4 | labuhan
# Processing Record 8 of Set 4 | vaini
# Processing Record 9 of Set 4 | cerrito
# Processing Record 10 of Set 4 | igunga
# Processing Record 11 of Set 4 | dunedin
# Processing Record 12 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 4 | guerrero negro
# Processing Record 14 of Set 4 | ribeira grande
# Processing Record 15 of Set 4 | dongying
# Processing Record 16 of Set 4 | dauriya
# Processing Record 17 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | ketchikan
# Processing Record 20 of Set 4 | komsomolskiy
# Processing Record 21 of Set 4 | clermont
# Processing Record 22 of Set 4 | ouegoa
# Processing Record 23 of Set 4 | cobh
# Processing Record 24 of Set 4 | spruce grove
# Processing Record 25 of Set 4 | belle fourche
# Processing Record 26 of Set 4 | hambantota
# Processing Record 27 of Set 4 | sept-iles
# Processing Record 28 of Set 4 | georgetown
# Processing Record 29 of Set 4 | yumen
# Processing Record 30 of Set 4 | ambon
# Processing Record 31 of Set 4 | dosso
# Processing Record 32 of Set 4 | sao filipe
# Processing Record 33 of Set 4 | chipata
# Processing Record 34 of Set 4 | arraial do cabo
# Processing Record 35 of Set 4 | fortuna
# Processing Record 36 of Set 4 | souillac
# Processing Record 37 of Set 4 | kvarkeno
# Processing Record 38 of Set 4 | guayaramerin
# Processing Record 39 of Set 4 | umm kaddadah
# Processing Record 40 of Set 4 | conakry
# Processing Record 41 of Set 4 | olavarria
# Processing Record 42 of Set 4 | ilhabela
# Processing Record 43 of Set 4 | miranda
# Processing Record 44 of Set 4 | oistins
# Processing Record 45 of Set 4 | pafos
# Processing Record 46 of Set 4 | kirakira
# Processing Record 47 of Set 4 | port lincoln
# Processing Record 48 of Set 4 | gushikawa
# Processing Record 49 of Set 4 | goderich
# Processing Record 50 of Set 4 | pangai
# Processing Record 1 of Set 5 | yerbogachen
# Processing Record 2 of Set 5 | los llanos de aridane
# Processing Record 3 of Set 5 | salalah
# Processing Record 4 of Set 5 | lynn haven
# Processing Record 5 of Set 5 | oktyabrskoye
# Processing Record 6 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 5 | birobidzhan
# Processing Record 8 of Set 5 | port hardy
# Processing Record 9 of Set 5 | coihaique
# Processing Record 10 of Set 5 | bambous virieux
# Processing Record 11 of Set 5 | svetlyy
# Processing Record 12 of Set 5 | dikson
# Processing Record 13 of Set 5 | miedzyrzec podlaski
# Processing Record 14 of Set 5 | clyde river
# Processing Record 15 of Set 5 | banyo
# Processing Record 16 of Set 5 | solnechnyy
# Processing Record 17 of Set 5 | waiuku
# Processing Record 18 of Set 5 | torbay
# Processing Record 19 of Set 5 | berbera
# Processing Record 20 of Set 5 | sungairaya
# Processing Record 21 of Set 5 | grand forks
# Processing Record 22 of Set 5 | beringovskiy
# Processing Record 23 of Set 5 | urucara
# Processing Record 24 of Set 5 | chifeng
# Processing Record 25 of Set 5 | marseille
# Processing Record 26 of Set 5 | palmares
# Processing Record 27 of Set 5 | manokwari
# Processing Record 28 of Set 5 | glens falls
# Processing Record 29 of Set 5 | pinerovka
# Processing Record 30 of Set 5 | pisco
# Processing Record 31 of Set 5 | lagoa
# Processing Record 32 of Set 5 | sola
# Processing Record 33 of Set 5 | clinton
# Processing Record 34 of Set 5 | bandarbeyla
# Processing Record 35 of Set 5 | mount gambier
# Processing Record 36 of Set 5 | chuy
# Processing Record 37 of Set 5 | port blair
# Processing Record 38 of Set 5 | nouadhibou
# Processing Record 39 of Set 5 | lorengau
# Processing Record 40 of Set 5 | karratha
# Processing Record 41 of Set 5 | mahebourg
# Processing Record 42 of Set 5 | hasaki
# Processing Record 43 of Set 5 | beloha
# Processing Record 44 of Set 5 | yar-sale
# Processing Record 45 of Set 5 | kurilsk
# Processing Record 46 of Set 5 | coquimbo
# Processing Record 47 of Set 5 | zaysan
# Processing Record 48 of Set 5 | itoman
# Processing Record 49 of Set 5 | bengkulu
# Processing Record 50 of Set 5 | mar del plata
# Processing Record 1 of Set 6 | port-gentil
# Processing Record 2 of Set 6 | samagaltay
# Processing Record 3 of Set 6 | alice springs
# Processing Record 4 of Set 6 | uitenhage
# Processing Record 5 of Set 6 | namie
# Processing Record 6 of Set 6 | nicoya
# Processing Record 7 of Set 6 | neyshabur
# Processing Record 8 of Set 6 | mazara del vallo
# Processing Record 9 of Set 6 | plettenberg bay
# Processing Record 10 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 6 | iqaluit
# Processing Record 12 of Set 6 | lompoc
# Processing Record 13 of Set 6 | vanavara
# Processing Record 14 of Set 6 | college
# Processing Record 15 of Set 6 | omsukchan
# Processing Record 16 of Set 6 | cayenne
# Processing Record 17 of Set 6 | tucupita
# Processing Record 18 of Set 6 | sibolga
# Processing Record 19 of Set 6 | sechura
# Processing Record 20 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 6 | san ignacio
# Processing Record 22 of Set 6 | luderitz
# Processing Record 23 of Set 6 | santa cruz
# Processing Record 24 of Set 6 | westport
# Processing Record 25 of Set 6 | biak
# Processing Record 26 of Set 6 | victoria point
# Processing Record 27 of Set 6 | srednekolymsk
# Processing Record 28 of Set 6 | machinga
# Processing Record 29 of Set 6 | altamirano
# Processing Record 30 of Set 6 | havre-saint-pierre
# Processing Record 31 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 6 | matata
# Processing Record 33 of Set 6 | zyryanka
# Processing Record 34 of Set 6 | alugan
# Processing Record 35 of Set 6 | riyadh
# Processing Record 36 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 37 of Set 6 | newport
# Processing Record 38 of Set 6 | phon
# Processing Record 39 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 40 of Set 6 | maniitsoq
# Processing Record 41 of Set 6 | todos santos
# Processing Record 42 of Set 6 | ulladulla
# Processing Record 43 of Set 6 | nishihara
# Processing Record 44 of Set 6 | san carlos de bariloche
# Processing Record 45 of Set 6 | tura
# Processing Record 46 of Set 6 | ayan
# Processing Record 47 of Set 6 | iwanai
# Processing Record 48 of Set 6 | vila franca do campo
# Processing Record 49 of Set 6 | constitucion
# Processing Record 50 of Set 6 | sao joao da barra
# Processing Record 1 of Set 7 | brownwood
# Processing Record 2 of Set 7 | placido de castro
# Processing Record 3 of Set 7 | salo
# Processing Record 4 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 7 | klaksvik
# Processing Record 7 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 7 | carnarvon
# Processing Record 9 of Set 7 | lakatoro
# Processing Record 10 of Set 7 | ndjole
# Processing Record 11 of Set 7 | lata
# Processing Record 12 of Set 7 | burnie
# Processing Record 13 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 7 | pingzhuang
# Processing Record 16 of Set 7 | san juan
# Processing Record 17 of Set 7 | belfast
# Processing Record 18 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 7 | puerto carreno
# Processing Record 20 of Set 7 | isangel
# Processing Record 21 of Set 7 | sitka
# Processing Record 22 of Set 7 | denpasar
# Processing Record 23 of Set 7 | muli
# Processing Record 24 of Set 7 | tome-acu
# City not found. Skipping...
# Processing Record 25 of Set 7 | krasnoarmeysk
# Processing Record 26 of Set 7 | kuusamo
# Processing Record 27 of Set 7 | delvada
# Processing Record 28 of Set 7 | caraballeda
# Processing Record 29 of Set 7 | dukat
# Processing Record 30 of Set 7 | nizwa
# Processing Record 31 of Set 7 | gamboma
# Processing Record 32 of Set 7 | mut
# Processing Record 33 of Set 7 | yian
# City not found. Skipping...
# Processing Record 34 of Set 7 | longyearbyen
# Processing Record 35 of Set 7 | talara
# Processing Record 36 of Set 7 | two rivers
# Processing Record 37 of Set 7 | helong
# Processing Record 38 of Set 7 | kendallville
# Processing Record 39 of Set 7 | mogadishu
# Processing Record 40 of Set 7 | adrar
# Processing Record 41 of Set 7 | brattleboro
# Processing Record 42 of Set 7 | general roca
# Processing Record 43 of Set 7 | paita
# Processing Record 44 of Set 7 | shu
# Processing Record 45 of Set 7 | flin flon
# Processing Record 46 of Set 7 | orgun
# City not found. Skipping...
# Processing Record 47 of Set 7 | kitimat
# Processing Record 48 of Set 7 | seoul
# Processing Record 49 of Set 7 | merauke
# Processing Record 50 of Set 7 | tiksi
# Processing Record 1 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 8 | ibipeba
# Processing Record 3 of Set 8 | barcelos
# Processing Record 4 of Set 8 | ekhabi
# Processing Record 5 of Set 8 | tuatapere
# Processing Record 6 of Set 8 | kupang
# Processing Record 7 of Set 8 | athabasca
# Processing Record 8 of Set 8 | pinega
# Processing Record 9 of Set 8 | zlatoustovsk
# City not found. Skipping...
# Processing Record 10 of Set 8 | shenkursk
# Processing Record 11 of Set 8 | praia
# Processing Record 12 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 13 of Set 8 | luau
# Processing Record 14 of Set 8 | manggar
# Processing Record 15 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 8 | kargasok
# Processing Record 17 of Set 8 | rock springs
# Processing Record 18 of Set 8 | northam
# Processing Record 19 of Set 8 | mackay
# Processing Record 20 of Set 8 | bonthe
# Processing Record 21 of Set 8 | cidreira
# Processing Record 22 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 8 | wembley
# Processing Record 24 of Set 8 | rantauprapat
# Processing Record 25 of Set 8 | itarema
# Processing Record 26 of Set 8 | abu dhabi
# Processing Record 27 of Set 8 | kang
# Processing Record 28 of Set 8 | la rioja
# Processing Record 29 of Set 8 | cedar city
# Processing Record 30 of Set 8 | lithgow
# Processing Record 31 of Set 8 | clarence town
# Processing Record 32 of Set 8 | kapit
# Processing Record 33 of Set 8 | abdulino
# Processing Record 34 of Set 8 | kaeo
# Processing Record 35 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 8 | willowmore
# Processing Record 37 of Set 8 | bani walid
# Processing Record 38 of Set 8 | te anau
# Processing Record 39 of Set 8 | ler
# Processing Record 40 of Set 8 | thompson
# Processing Record 41 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 8 | salinopolis
# Processing Record 43 of Set 8 | asfi
# Processing Record 44 of Set 8 | nanchang
# Processing Record 45 of Set 8 | la ronge
# Processing Record 46 of Set 8 | kilindoni
# Processing Record 47 of Set 8 | vestmannaeyjar
# Processing Record 48 of Set 8 | smidovich
# Processing Record 49 of Set 8 | chicama
# Processing Record 50 of Set 8 | tabou
# Processing Record 1 of Set 9 | lagos
# Processing Record 2 of Set 9 | narsaq
# Processing Record 3 of Set 9 | lavrentiya
# Processing Record 4 of Set 9 | nyurba
# Processing Record 5 of Set 9 | ilulissat
# Processing Record 6 of Set 9 | nanortalik
# Processing Record 7 of Set 9 | muros
# Processing Record 8 of Set 9 | cockburn town
# Processing Record 9 of Set 9 | ushtobe
# Processing Record 10 of Set 9 | katsuura
# Processing Record 11 of Set 9 | yulara
# Processing Record 12 of Set 9 | kracheh
# City not found. Skipping...
# Processing Record 13 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 14 of Set 9 | broome
# Processing Record 15 of Set 9 | belaya gora
# Processing Record 16 of Set 9 | bobonong
# City not found. Skipping...
# Processing Record 17 of Set 9 | kerkira
# City not found. Skipping...
# Processing Record 18 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 9 | athens
# Processing Record 20 of Set 9 | daru
# Processing Record 21 of Set 9 | darfo
# Processing Record 22 of Set 9 | laguna de perlas
# Processing Record 23 of Set 9 | kimberley
# Processing Record 24 of Set 9 | kavaratti
# Processing Record 25 of Set 9 | guanica
# Processing Record 26 of Set 9 | nome
# Processing Record 27 of Set 9 | tromso
# Processing Record 28 of Set 9 | buraydah
# Processing Record 29 of Set 9 | martapura
# Processing Record 30 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 9 | ostra
# Processing Record 32 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 9 | portland
# Processing Record 34 of Set 9 | sorong
# Processing Record 35 of Set 9 | vilhena
# Processing Record 36 of Set 9 | hearst
# Processing Record 37 of Set 9 | bahia blanca
# Processing Record 38 of Set 9 | batsfjord
# Processing Record 39 of Set 9 | chapais
# Processing Record 40 of Set 9 | butajira
# Processing Record 41 of Set 9 | ponta delgada
# Processing Record 42 of Set 9 | vardo
# Processing Record 43 of Set 9 | aksu
# Processing Record 44 of Set 9 | corinto
# Processing Record 45 of Set 9 | anloga
# Processing Record 46 of Set 9 | roald
# Processing Record 47 of Set 9 | alta floresta
# Processing Record 48 of Set 9 | labytnangi
# Processing Record 49 of Set 9 | gairo
# Processing Record 50 of Set 9 | kenora
# Processing Record 1 of Set 10 | taicheng
# Processing Record 2 of Set 10 | port macquarie
# Processing Record 3 of Set 10 | xichang
# Processing Record 4 of Set 10 | dharchula
# Processing Record 5 of Set 10 | mikuni
# Processing Record 6 of Set 10 | sorland
# Processing Record 7 of Set 10 | meulaboh
# Processing Record 8 of Set 10 | nioro
# Processing Record 9 of Set 10 | ust-tsilma
# Processing Record 10 of Set 10 | springdale
# Processing Record 11 of Set 10 | novoagansk
# Processing Record 12 of Set 10 | jinka
# Processing Record 13 of Set 10 | codajas
# Processing Record 14 of Set 10 | vila do maio
# Processing Record 15 of Set 10 | los aquijes
# Processing Record 16 of Set 10 | puerto el triunfo
# Processing Record 17 of Set 10 | viedma
# Processing Record 18 of Set 10 | poum
# Processing Record 19 of Set 10 | sioux lookout
# Processing Record 20 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 10 | pangnirtung
# Processing Record 22 of Set 10 | ximei
# Processing Record 23 of Set 10 | ekibastuz
# Processing Record 24 of Set 10 | elk city
# Processing Record 25 of Set 10 | mehamn
# Processing Record 26 of Set 10 | baiquan
# Processing Record 27 of Set 10 | boquete
# Processing Record 28 of Set 10 | sidi ali
# Processing Record 29 of Set 10 | tamsweg
# Processing Record 30 of Set 10 | abu kamal
# Processing Record 31 of Set 10 | launceston
# Processing Record 32 of Set 10 | awjilah
# Processing Record 33 of Set 10 | maldonado
# Processing Record 34 of Set 10 | auras
# Processing Record 35 of Set 10 | rehoboth
# Processing Record 36 of Set 10 | almaznyy
# Processing Record 37 of Set 10 | harrisburg
# Processing Record 38 of Set 10 | clyde
# Processing Record 39 of Set 10 | inhambane
# Processing Record 40 of Set 10 | sirajganj
# Processing Record 41 of Set 10 | ponta do sol
# Processing Record 42 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 10 | udachnyy
# Processing Record 44 of Set 10 | amapa
# Processing Record 45 of Set 10 | punganuru
# Processing Record 46 of Set 10 | shizuishan
# Processing Record 47 of Set 10 | lazaro cardenas
# Processing Record 48 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 10 | hualmay
# Processing Record 50 of Set 10 | zhumadian
# Processing Record 1 of Set 11 | bud
# Processing Record 2 of Set 11 | semey
# Processing Record 3 of Set 11 | turan
# Processing Record 4 of Set 11 | finnsnes
# Processing Record 5 of Set 11 | jiuquan
# Processing Record 6 of Set 11 | stawell
# Processing Record 7 of Set 11 | saint-francois
# Processing Record 8 of Set 11 | okakarara
# Processing Record 9 of Set 11 | artyshta
# Processing Record 10 of Set 11 | mitu
# Processing Record 11 of Set 11 | kamaishi
# Processing Record 12 of Set 11 | jijiga
# Processing Record 13 of Set 11 | beaufort
# Processing Record 14 of Set 11 | pionerskiy
# Processing Record 15 of Set 11 | harlingen
# Processing Record 16 of Set 11 | pangody
# Processing Record 17 of Set 11 | pundaguitan
# Processing Record 18 of Set 11 | saint-pierre
# Processing Record 19 of Set 11 | zhigansk
# Processing Record 20 of Set 11 | ucluelet
# Processing Record 21 of Set 11 | rapid city
# Processing Record 22 of Set 11 | tremedal
# Processing Record 23 of Set 11 | radcliff
# Processing Record 24 of Set 11 | panzhihua
# Processing Record 25 of Set 11 | zanzibar
# Processing Record 26 of Set 11 | olinda
# Processing Record 27 of Set 11 | cam ranh
# Processing Record 28 of Set 11 | eskisehir
# Processing Record 29 of Set 11 | stanger
# Processing Record 30 of Set 11 | huayang
# Processing Record 31 of Set 11 | nsoko
# Processing Record 32 of Set 11 | porto seguro
# Processing Record 33 of Set 11 | abhaynagar
# Processing Record 34 of Set 11 | acurenam
# Processing Record 35 of Set 11 | kholtoson
# Processing Record 36 of Set 11 | kosh-agach
# Processing Record 37 of Set 11 | karasburg
# Processing Record 38 of Set 11 | balkanabat
# Processing Record 39 of Set 11 | xinzhi
# Processing Record 40 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 11 | inuvik
# Processing Record 42 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 43 of Set 11 | ambilobe
# Processing Record 44 of Set 11 | ifanadiana
# Processing Record 45 of Set 11 | oktyabrskiy
# Processing Record 46 of Set 11 | yanam
# Processing Record 47 of Set 11 | samarai
# Processing Record 48 of Set 11 | ca mau
# Processing Record 49 of Set 11 | alexandria
# Processing Record 50 of Set 11 | port hedland
# Processing Record 1 of Set 12 | chiredzi
# Processing Record 2 of Set 12 | praya
# Processing Record 3 of Set 12 | salto
# Processing Record 4 of Set 12 | matagami
# Processing Record 5 of Set 12 | gamba
# Processing Record 6 of Set 12 | westerland
# Processing Record 7 of Set 12 | cheyenne
# Processing Record 8 of Set 12 | catamarca
# Processing Record 9 of Set 12 | axim
# Processing Record 10 of Set 12 | hovd
# Processing Record 11 of Set 12 | whitehorse
# Processing Record 12 of Set 12 | tangwani
# Processing Record 13 of Set 12 | noumea
# Processing Record 14 of Set 12 | tezu
# Processing Record 15 of Set 12 | najran
# Processing Record 16 of Set 12 | tyazhinskiy
# Processing Record 17 of Set 12 | buenos aires
# Processing Record 18 of Set 12 | yugorsk
# Processing Record 19 of Set 12 | tahoua
# Processing Record 20 of Set 12 | namibe
# Processing Record 21 of Set 12 | cherskiy
# Processing Record 22 of Set 12 | bambanglipuro
# Processing Record 23 of Set 12 | williams lake
# Processing Record 24 of Set 12 | mumford
# Processing Record 25 of Set 12 | deshna
# City not found. Skipping...
# Processing Record 26 of Set 12 | boguchany
# Processing Record 27 of Set 12 | broken hill
# Processing Record 28 of Set 12 | salinas
# Processing Record 29 of Set 12 | el alto
# Processing Record 30 of Set 12 | calca
# Processing Record 31 of Set 12 | maarianhamina
# Processing Record 32 of Set 12 | neuquen
# Processing Record 33 of Set 12 | irtyshskiy
# Processing Record 34 of Set 12 | palmer
# Processing Record 35 of Set 12 | abrau-dyurso
# Processing Record 36 of Set 12 | myre
# Processing Record 37 of Set 12 | muscatine
# Processing Record 38 of Set 12 | kloulklubed
# Processing Record 39 of Set 12 | gornopravdinsk
# Processing Record 40 of Set 12 | lokosovo
# Processing Record 41 of Set 12 | biltine
# Processing Record 42 of Set 12 | kahului
# Processing Record 43 of Set 12 | garmsar
# Processing Record 44 of Set 12 | camalu
# Processing Record 45 of Set 12 | gat
# Processing Record 46 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 47 of Set 12 | puerto leguizamo
# Processing Record 48 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 12 | hirara
# Processing Record 50 of Set 12 | marondera
# Processing Record 1 of Set 13 | amuntai
# Processing Record 2 of Set 13 | yueyang
# Processing Record 3 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 4 of Set 13 | muslyumovo
# Processing Record 5 of Set 13 | antofagasta
# Processing Record 6 of Set 13 | srandakan
# Processing Record 7 of Set 13 | homer
# Processing Record 8 of Set 13 | pacific grove
# Processing Record 9 of Set 13 | teknaf
# Processing Record 10 of Set 13 | maple creek
# Processing Record 11 of Set 13 | bereda
# Processing Record 12 of Set 13 | oussouye
# Processing Record 13 of Set 13 | aswan
# Processing Record 14 of Set 13 | saint anthony
# Processing Record 15 of Set 13 | sisimiut
# Processing Record 16 of Set 13 | ocampo
# Processing Record 17 of Set 13 | san vicente
# Processing Record 18 of Set 13 | caravelas
# Processing Record 19 of Set 13 | douglas
# Processing Record 20 of Set 13 | ambulu
# Processing Record 21 of Set 13 | vostok
# Processing Record 22 of Set 13 | rawson
# Processing Record 23 of Set 13 | selma
# Processing Record 24 of Set 13 | dickinson
# Processing Record 25 of Set 13 | vanimo
# Processing Record 26 of Set 13 | boyolangu
# Processing Record 27 of Set 13 | fort nelson
# Processing Record 28 of Set 13 | asau
# Processing Record 29 of Set 13 | bull savanna
# Processing Record 30 of Set 13 | oga
# Processing Record 31 of Set 13 | khovu-aksy
# Processing Record 32 of Set 13 | yining
# Processing Record 33 of Set 13 | mersing
# Processing Record 34 of Set 13 | lucapa
# Processing Record 35 of Set 13 | santiago tuxtla
# Processing Record 36 of Set 13 | candawaga
# City not found. Skipping...
# Processing Record 37 of Set 13 | turtas
# Processing Record 38 of Set 13 | benguela
# Processing Record 39 of Set 13 | damietta
# Processing Record 40 of Set 13 | huilong
# Processing Record 41 of Set 13 | gravelbourg
# Processing Record 42 of Set 13 | corn island
# Processing Record 43 of Set 13 | amahai
# Processing Record 44 of Set 13 | andreyevo
# Processing Record 45 of Set 13 | crawfordsville
# Processing Record 46 of Set 13 | wanning
# Processing Record 47 of Set 13 | kenai
# Processing Record 48 of Set 13 | dudinka
# Processing Record 49 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 50 of Set 13 | terrace
# Processing Record 1 of Set 14 | show low
# Processing Record 2 of Set 14 | yuza
# Processing Record 3 of Set 14 | bukachacha
# Processing Record 4 of Set 14 | luang prabang
# Processing Record 5 of Set 14 | dumai
# Processing Record 6 of Set 14 | qaqortoq
# Processing Record 7 of Set 14 | padang
# Processing Record 8 of Set 14 | san roque
# Processing Record 9 of Set 14 | tucuman
# Processing Record 10 of Set 14 | mahibadhoo
# Processing Record 11 of Set 14 | olafsvik
# Processing Record 12 of Set 14 | kununurra
# Processing Record 13 of Set 14 | arica
# Processing Record 14 of Set 14 | galveston
# Processing Record 15 of Set 14 | haimen
# Processing Record 16 of Set 14 | tambovka
# Processing Record 17 of Set 14 | chegdomyn
# Processing Record 18 of Set 14 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 19 of Set 14 | dhidhdhoo
# Processing Record 20 of Set 14 | kieta
# Processing Record 21 of Set 14 | soyo
# Processing Record 22 of Set 14 | banepa
# Processing Record 23 of Set 14 | shache
# Processing Record 24 of Set 14 | itamaraca
# Processing Record 25 of Set 14 | bundaberg
# Processing Record 26 of Set 14 | ankang
# Processing Record 27 of Set 14 | sainte-adele
# Processing Record 28 of Set 14 | blonduos
# City not found. Skipping...
# Processing Record 29 of Set 14 | grand island
# Processing Record 30 of Set 14 | baddomalhi
# Processing Record 31 of Set 14 | mocuba
# Processing Record 32 of Set 14 | atambua
# Processing Record 33 of Set 14 | fairbanks
# Processing Record 34 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 14 | mandalgovi
# Processing Record 36 of Set 14 | midland
# Processing Record 37 of Set 14 | xinqing
# Processing Record 38 of Set 14 | pendleton
# Processing Record 39 of Set 14 | marsa matruh
# Processing Record 40 of Set 14 | galle
# Processing Record 41 of Set 14 | itacoatiara
# Processing Record 42 of Set 14 | nelson bay
# Processing Record 43 of Set 14 | richards bay
# Processing Record 44 of Set 14 | kidal
# Processing Record 45 of Set 14 | baruun-urt
# Processing Record 46 of Set 14 | grindavik
# Processing Record 47 of Set 14 | khandyga
# Processing Record 48 of Set 14 | le port
# Processing Record 49 of Set 14 | bocaranga
# City not found. Skipping...
# Processing Record 50 of Set 14 | dingle
# Processing Record 1 of Set 15 | sumenep
# Processing Record 2 of Set 15 | christchurch
# Processing Record 3 of Set 15 | rafai
# Processing Record 4 of Set 15 | san-pedro
# Processing Record 5 of Set 15 | mount isa
# Processing Record 6 of Set 15 | tommot
# Processing Record 7 of Set 15 | paamiut
# Processing Record 8 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 15 | tigre
# Processing Record 11 of Set 15 | ridgecrest
# Processing Record 12 of Set 15 | berlevag
# Processing Record 13 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 15 | chumikan
# Processing Record 15 of Set 15 | labrea
# Processing Record 16 of Set 15 | cuamba
# Processing Record 17 of Set 15 | batagay-alyta
# Processing Record 18 of Set 15 | avera
# Processing Record 19 of Set 15 | sogne
# Processing Record 20 of Set 15 | port victoria
# Processing Record 21 of Set 15 | san patricio
# Processing Record 22 of Set 15 | alekseyevsk
# Processing Record 23 of Set 15 | napanee
# Processing Record 24 of Set 15 | mollendo
# Processing Record 25 of Set 15 | belyy yar
# Processing Record 26 of Set 15 | la asuncion
# Processing Record 27 of Set 15 | monte patria
# Processing Record 28 of Set 15 | moose factory
# Processing Record 29 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 30 of Set 15 | aleksandrov gay
# Processing Record 31 of Set 15 | rosario
# Processing Record 32 of Set 15 | sinnamary
# Processing Record 33 of Set 15 | at-bashi
# Processing Record 34 of Set 15 | teguise
# Processing Record 35 of Set 15 | sabha
# Processing Record 36 of Set 15 | hervey bay
# Processing Record 37 of Set 15 | ozernovskiy
# Processing Record 38 of Set 15 | sukhobezvodnoye
# Processing Record 39 of Set 15 | terrell
# Processing Record 40 of Set 15 | manono
# Processing Record 41 of Set 15 | massape
# Processing Record 42 of Set 15 | jagdalpur
# Processing Record 43 of Set 15 | jalu
# Processing Record 44 of Set 15 | matameye
# City not found. Skipping...
# Processing Record 45 of Set 15 | puerto del rosario
# Processing Record 46 of Set 15 | raudeberg
# Processing Record 47 of Set 15 | vredendal
# Processing Record 48 of Set 15 | san miguel
# Processing Record 49 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 15 | petatlan
# Processing Record 1 of Set 16 | port-cartier
# Processing Record 2 of Set 16 | liverpool
# Processing Record 3 of Set 16 | saint-augustin
# Processing Record 4 of Set 16 | jacqueville
# Processing Record 5 of Set 16 | chalette-sur-loing
# Processing Record 6 of Set 16 | nan
# Processing Record 7 of Set 16 | lagos de moreno
# Processing Record 8 of Set 16 | makakilo city
# Processing Record 9 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 16 | cap-aux-meules
# Processing Record 11 of Set 16 | moskovskiy
# Processing Record 12 of Set 16 | hedaru
# Processing Record 13 of Set 16 | puerto salgar
# Processing Record 14 of Set 16 | saint-joseph
# Processing Record 15 of Set 16 | namatanai
# Processing Record 16 of Set 16 | the pas
# Processing Record 17 of Set 16 | tiznit
# Processing Record 18 of Set 16 | zhangye
# Processing Record 19 of Set 16 | nogliki
# Processing Record 20 of Set 16 | rey bouba
# Processing Record 21 of Set 16 | presidencia roque saenz pena
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Upernavik      GL  72.7868  -56.1549     41.25        81          12
# 1  Cape Town      ZA -33.9258   18.4232     62.11        54           0
# 2  Busselton      AU -33.6500  115.3333     58.08        65           8
# 3       Abha      SA  18.2164   42.5053     66.02        94         100
# 4    Kebumen      ID  -7.6687  109.6519     71.80        90          23
# 5    Zenzeli      RU  45.9241   47.0474     78.33        37           0
# 6      Mweka      CD  -4.8500   21.5667     73.24        35           7
# 7  Xiongzhou      CN  25.1167  114.3000     78.49        85          85
# 8    Aasiaat      GL  68.7098  -52.8699     40.06        76         100
# 9    Rikitea      PF -23.1203 -134.9692     70.65        67          38
#
#    Wind Speed Current Description
# 0       13.24          few clouds
# 1        3.44           clear sky
# 2       20.58           clear sky
# 3        2.30     overcast clouds
# 4        4.12          few clouds
# 5        4.72           clear sky
# 6        2.84           clear sky
# 7        0.89     overcast clouds
# 8       12.08     overcast clouds
# 9        6.42    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
